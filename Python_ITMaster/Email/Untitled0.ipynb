# %%
import smtplib

#caragamos el dominio del correo
smtp_object = smtplib.SMTP('smtp.gmail.com')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-7996f85a8ed9> in <module>()
#       2
#       3 #caragamos el dominio del correo
# ----> 4 smtp_object = smtplib.SMTP('smtp.gmail.com')
#
# /usr/lib/python3.7/smtplib.py in __init__(self, host, port, local_hostname, timeout, source_address)
#     249
#     250         if host:
# --> 251             (code, msg) = self.connect(host, port)
#     252             if code != 220:
#     253                 self.close()
#
# /usr/lib/python3.7/smtplib.py in connect(self, host, port, source_address)
#     334         if self.debuglevel > 0:
#     335             self._print_debug('connect:', (host, port))
# --> 336         self.sock = self._get_socket(host, port, self.timeout)
#     337         self.file = None
#     338         (code, msg) = self.getreply()
#
# ...

# %%
#Al momento de hacer la practica no me pude conectar al servidor de Gmail

#Este primer paso es necesario
smtp_object.ehlo()

# %%
#La forma correcta de pedir la contraseña es sin que se vea
import getpass

password = getpass.getpass('Por favor ingrese la contraseña: ')
# Out:
# Por favor ingrese la contraseña: ··········
