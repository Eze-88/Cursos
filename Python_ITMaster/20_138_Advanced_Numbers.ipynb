# %%
#Conversion a formato hexadecimal
print(hex(16))
# Out:
# 0x10

# %%
#Conversion a formato binario
print(bin(16))
# Out:
# 0b10000

# %%
# Elevar a cierta potencia (base,exponente,modulo)
print(pow(2,4))
print(pow(2,4,1))
# Out:
# 16
# 0

# %%
#Valor absoluto
print(abs(-3))
print(abs(3))
# Out:
# 3
# 3

# %%
#Redondeo
print(round(3.3))
print(round(3))
print(round(3.14159,2))
# Out:
# 3
# 3
# 3.14
